# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('cleaned_data.csv')

# %%
df.head()
# Out:
#               Name   Location    Salary  \
# 0           Indeed  Hyderābād  54 - 80
# 1       Mastercard    Gurgaon    2 - 3
# 2           MathCo  Bengaluru   8 - 10
# 3               ZS    Gurgaon   4 - 10
# 4  SUGAR Cosmetics     Mumbai    3 - 5
#
#                                          Description
# 0  Articulate and document best practices and des...
# 1  All activities involving access to Mastercard ...
# 2  Performs research for solutions and solves pro...
# 3  Being part of the ADS group at ZS will be an o...
# 4  Stay current with Python libraries and data an...

# %%
df.columns
# Out:
# Index(['Name', 'Location', 'Salary', 'Description'], dtype='object')

# %%
df['desc_len']=df['Description'].apply(lambda x:len(x))

# %%
df['desc_len']
# Out:
# 0      122
# 1      160
# 2      162
# 3      160
# 4      149
#       ...
# 546    154
# 547    158
# 548    128
# 549    161
# 550    161
# Name: desc_len, Length: 551, dtype: int64

# %%
df['max_salary'] = df['Salary'].str.split('-').str.get(0)
df['min_salary'] = df['Salary'].str.split('-').str.get(1)

# %%
df['min_salary'] = df['min_salary'].fillna(df['max_salary'])
df['max_salary'] = df['max_salary'].fillna(df['min_salary'])

# %%
df
# Out:
#                            Name   Location    Salary  \
# 0                        Indeed  Hyderābād  54 - 80
# 1                    Mastercard    Gurgaon    2 - 3
# 2                        MathCo  Bengaluru   8 - 10
# 3                            ZS    Gurgaon   4 - 10
# 4               SUGAR Cosmetics     Mumbai    3 - 5
# ..                          ...        ...       ...
# 546                  FIS Global  Bengaluru   6 - 10
# 547                      Irdeto  New Delhi    6 - 8
# 548                   Foraysoft    Gurgaon    5 - 8
# 549               Roland Berger     Mumbai    6 - 9
# 550  NeoQuant Solutions Pvt Ltd     Mumbai   4 - 16
#
#                                            Description  desc_len max_salary  \
# 0    Articulate and document best practices and des...       122        54
# 1    All activities involving access to Mastercard ...       160         2
# 2    Performs research for solutions and solves pro...       162         8
# ...

# %%
df['Average_salary'] = np.mean(df[['min_salary', 'max_salary']], axis=1)
# Out:
# C:\Users\harshittiwari\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
df
# Out:
#                            Name   Location    Salary  \
# 0                        Indeed  Hyderābād  54 - 80
# 1                    Mastercard    Gurgaon    2 - 3
# 2                        MathCo  Bengaluru   8 - 10
# 3                            ZS    Gurgaon   4 - 10
# 4               SUGAR Cosmetics     Mumbai    3 - 5
# ..                          ...        ...       ...
# 546                  FIS Global  Bengaluru   6 - 10
# 547                      Irdeto  New Delhi    6 - 8
# 548                   Foraysoft    Gurgaon    5 - 8
# 549               Roland Berger     Mumbai    6 - 9
# 550  NeoQuant Solutions Pvt Ltd     Mumbai   4 - 16
#
#                                            Description  desc_len max_salary  \
# 0    Articulate and document best practices and des...       122        54
# 1    All activities involving access to Mastercard ...       160         2
# 2    Performs research for solutions and solves pro...       162         8
# ...

# %%
avg= pd.DataFrame({'min_salary', 'max_salary'})

# Calculate the average of the two columns
df['average_salary'] = df.mean(axis=1)
# Out:
# C:\Users\harshittiwari\AppData\Local\Temp\ipykernel_13128\900725563.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['average_salary'] = df.mean(axis=1)

# %%
df
# Out:
#                            Name   Location    Salary  \
# 0                        Indeed  Hyderābād  54 - 80
# 1                    Mastercard    Gurgaon    2 - 3
# 2                        MathCo  Bengaluru   8 - 10
# 3                            ZS    Gurgaon   4 - 10
# 4               SUGAR Cosmetics     Mumbai    3 - 5
# ..                          ...        ...       ...
# 546                  FIS Global  Bengaluru   6 - 10
# 547                      Irdeto  New Delhi    6 - 8
# 548                   Foraysoft    Gurgaon    5 - 8
# 549               Roland Berger     Mumbai    6 - 9
# 550  NeoQuant Solutions Pvt Ltd     Mumbai   4 - 16
#
#                                            Description  desc_len max_salary  \
# 0    Articulate and document best practices and des...       122        54
# 1    All activities involving access to Mastercard ...       160         2
# 2    Performs research for solutions and solves pro...       162         8
# ...

# %%
df = df.drop(columns=['Average_salary'])

# %%
df = df.drop(columns=['average_salary'])

# %%
df
# Out:
#                            Name   Location    Salary  \
# 0                        Indeed  Hyderābād  54 - 80
# 1                    Mastercard    Gurgaon    2 - 3
# 2                        MathCo  Bengaluru   8 - 10
# 3                            ZS    Gurgaon   4 - 10
# 4               SUGAR Cosmetics     Mumbai    3 - 5
# ..                          ...        ...       ...
# 546                  FIS Global  Bengaluru   6 - 10
# 547                      Irdeto  New Delhi    6 - 8
# 548                   Foraysoft    Gurgaon    5 - 8
# 549               Roland Berger     Mumbai    6 - 9
# 550  NeoQuant Solutions Pvt Ltd     Mumbai   4 - 16
#
#                                            Description  desc_len max_salary  \
# 0    Articulate and document best practices and des...       122        54
# 1    All activities involving access to Mastercard ...       160         2
# 2    Performs research for solutions and solves pro...       162         8
# ...

# %%
df
# Out:
#                            Name   Location    Salary  \
# 0                        Indeed  Hyderābād  54 - 80
# 1                    Mastercard    Gurgaon    2 - 3
# 2                        MathCo  Bengaluru   8 - 10
# 3                            ZS    Gurgaon   4 - 10
# 4               SUGAR Cosmetics     Mumbai    3 - 5
# ..                          ...        ...       ...
# 546                  FIS Global  Bengaluru   6 - 10
# 547                      Irdeto  New Delhi    6 - 8
# 548                   Foraysoft    Gurgaon    5 - 8
# 549               Roland Berger     Mumbai    6 - 9
# 550  NeoQuant Solutions Pvt Ltd     Mumbai   4 - 16
#
#                                            Description  desc_len max_salary  \
# 0    Articulate and document best practices and des...       122        54
# 1    All activities involving access to Mastercard ...       160         2
# 2    Performs research for solutions and solves pro...       162         8
# ...

# %%
df['max_salary'] = df['max_salary'].str.replace('Per hour', '')

# %%
df['max_salary'] = df['max_salary'].apply(lambda x: x.strip())

# %%
df['max_salary'] = df['max_salary'].str.replace(',', '')

# %%
df['max_salary'] = pd.to_numeric(df['max_salary'], downcast='integer')

# %%
df['min_salary'] = df['min_salary'].str.replace('Per hour', '')
df['min_salary'] = df['min_salary'].apply(lambda x: x.strip())
df['min_salary'] = df['min_salary'].str.replace(',', '')
df['min_salary'] = pd.to_numeric(df['min_salary'], downcast='integer')

# %%
df['avg_salary'] = df[['max_salary', 'min_salary']].mean(axis=1)

# %%
df
# Out:
#                            Name   Location    Salary  \
# 0                        Indeed  Hyderābād  54 - 80
# 1                    Mastercard    Gurgaon    2 - 3
# 2                        MathCo  Bengaluru   8 - 10
# 3                            ZS    Gurgaon   4 - 10
# 4               SUGAR Cosmetics     Mumbai    3 - 5
# ..                          ...        ...       ...
# 546                  FIS Global  Bengaluru   6 - 10
# 547                      Irdeto  New Delhi    6 - 8
# 548                   Foraysoft    Gurgaon    5 - 8
# 549               Roland Berger     Mumbai    6 - 9
# 550  NeoQuant Solutions Pvt Ltd     Mumbai   4 - 16
#
#                                            Description  desc_len  max_salary  \
# 0    Articulate and document best practices and des...       122          54
# 1    All activities involving access to Mastercard ...       160           2
# 2    Performs research for solutions and solves pro...       162           8
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                            Name   Location    Salary  \
# 0                        Indeed  Hyderābād  54 - 80
# 1                    Mastercard    Gurgaon    2 - 3
# 2                        MathCo  Bengaluru   8 - 10
# 3                            ZS    Gurgaon   4 - 10
# 4               SUGAR Cosmetics     Mumbai    3 - 5
# ..                          ...        ...       ...
# 546                  FIS Global  Bengaluru   6 - 10
# 547                      Irdeto  New Delhi    6 - 8
# 548                   Foraysoft    Gurgaon    5 - 8
# 549               Roland Berger     Mumbai    6 - 9
# 550  NeoQuant Solutions Pvt Ltd     Mumbai   4 - 16
#
#                                            Description  desc_len  max_salary  \
# 0    Articulate and document best practices and des...       122          54
# 1    All activities involving access to Mastercard ...       160           2
# ...

# %%
df.avg_salary.hist(ec="black")
# Out:
# <AxesSubplot: >

# %%
df[['avg_salary','desc_len','Location']].corr()
# Out:
# C:\Users\harshittiwari\AppData\Local\Temp\ipykernel_13128\3858840424.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[['avg_salary','desc_len','Location']].corr()
#             avg_salary  desc_len
# avg_salary    1.000000 -0.032056
# desc_len     -0.032056  1.000000

# %%
import seaborn as sns
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(df[['avg_salary','desc_len','Location']].corr(), vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# C:\Users\harshittiwari\AppData\Local\Temp\ipykernel_13128\1265980017.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df[['avg_salary','desc_len','Location']].corr(), vmax=.3, center=0,
# <AxesSubplot: >

# %%
df_cat=df[['Location','Description','desc_len','Name','avg_salary']]

# %%
for i in df_cat.columns:
    cat_num=df_cat[i].value_counts()
    print("graph for %s: total=%d" %(i,len(cat_num)))
    chart=sns.barplot(x=cat_num.index,y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total=53
# graph for Description: total=534
# C:\Users\harshittiwari\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 61623 (\uf0b7) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\harshittiwari\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 61607 (\uf0a7) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\harshittiwari\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 61608 (\uf0a8) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\harshittiwari\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 61692 (\uf0fc) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# graph for desc_len: total=51
# ...

# %%
for i in df_cat[['Location','Name','avg_salary']]:
    cat_num=df_cat[i].value_counts()[:20]
    print("graph for %s: total=%d" %(i,len(cat_num)))
    chart=sns.barplot(x=cat_num.index,y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total=20
# graph for Name: total=20
# graph for avg_salary: total=22

# %%
pd.pivot_table(df,index='Location',values='avg_salary')
# Out:
#                     avg_salary
# Location
# Ahmedabad             7.900000
# Aurangābād            5.000000
# Bahādurgarh           4.500000
# Bengaluru             9.108108
# Bhopal               70.000000
# Bokāro                6.000000
# Bārāsat              40.500000
# Calcutta              8.200000
# Calicut              10.000000
# Chandigarh           10.666667
# Chennai               7.886364
# Cochin                9.800000
# Coimbatore            5.833333
# Delhi                32.500000
# Eranakulam            1.000000
# Gurgaon              13.394737
# Gwalior              10.000000
# Gāndhīnagar           6.500000
# Haryāna               8.500000
# Hyderābād            32.046512
# India                18.470588
# Indore               18.181818
# Jaipur               10.666667
# Jamshedpur            6.500000
# Karnāl                8.500000
# Kottayam             11.500000
# Lucknow               4.000000
# Mohali               25.250000
# ...

# %%
pd.pivot_table(df,index='Location',values='avg_salary').sort_values('avg_salary',ascending=False)
# Out:
#                     avg_salary
# Location
# Remote              125.300000
# Nagercoil            90.000000
# Bhopal               70.000000
# Sasarām              68.000000
# Bārāsat              40.500000
# Māvelikara           40.000000
# Delhi                32.500000
# Hyderābād            32.046512
# Mohali               25.250000
# Telangana            20.000000
# India                18.470588
# Indore               18.181818
# Gurgaon              13.394737
# Tīra Sujānpur        12.000000
# Thāne                11.800000
# Kottayam             11.500000
# Navi Mumbai          11.500000
# Chandigarh           10.666667
# Jaipur               10.666667
# Gwalior              10.000000
# Calicut              10.000000
# Cochin                9.800000
# Noida                 9.774194
# Bengaluru             9.108108
# New Delhi             9.062500
# Sheohar               8.500000
# Haryāna               8.500000
# Karnāl                8.500000
# ...

# %%
pd.pivot_table(df[df.Location=='Bengaluru'],index='Location',values='avg_salary',aggfunc='count').sort_values('avg_salary',ascending=False)
# Out:
#            avg_salary
# Location
# Bengaluru         148

# %%
df.columns
# Out:
# Index(['Name', 'Location', 'Salary', 'Description', 'desc_len', 'max_salary',
#        'min_salary', 'avg_salary'],
#       dtype='object')

# %%
# !pip install wordcloud
# !pip install nltk

import nltk

nltk.download('punkt')
nltk.download("stopwords")
from wordcloud import WordCloud,ImageColorGenerator,STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# ...
# [notice] A new release of pip is available: 23.0 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\harshittiwari\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\harshittiwari\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from string import punctuation



words=" ".join(df['Description'])
def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered=[]
    stop_words=set(stopwords.words('english'))
    word_tokens=word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered
words_filtered=punctuation_stop(words)
text=" ".join([ele for ele in words_filtered])
words = " ".join(df['Description'])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()
